# %% [markdown]
# # Table of Contents
# ## This script contains the following:
# 1. Import libraries
# 2. Import Data
# 3. Data Cleaning
# 4. Data Consistency Checks
# 5. Export

# %% [markdown]
# # 1.0 Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Set options to display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 2.0 Importing Data

# %%
# Create path for main project folder
path = r'/Users/sharnti/Desktop/CareerFoundry/Data Immersion/Achievement 6/Project'

# %%
# Test path has been created
path
# Out:
# '/Users/sharnti/Desktop/CareerFoundry/Data Immersion/Achievement 6/Project'

# %% [markdown]
# ## 2.1 Tsunami Dataset

# %% [markdown]
# ### 2.1.1 Import Data for 1985-1994

# %%
# Import runups_1985-1994.tsv dataset
runups_1985_1994 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data','runups_1985-1994.tsv'),sep='\t')

# %%
# Print first 5 rows of dataframe
runups_1985_1994.head()
# Out:
#           Search Parameters    Year   Mo   Dy    Hr    Mn  Sec  \
# 0  ["1985 <= Year >= 1994"]     NaN  NaN  NaN   NaN   NaN  NaN
# 1                       NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 2                       NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 3                       NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 4                       NaN  1985.0  3.0  3.0  22.0  47.0  9.5
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 0                     NaN                 NaN      NaN                   NaN
# 1                     4.0                 1.0   2158.0                   8.0
# 2                     4.0                 1.0   2158.0                   8.0
# 3                     4.0                 1.0   2158.0                   8.0
# 4                     4.0                 1.0   2158.0                   8.0
#
#    Vol  More Info Doubtful Runup Country Area           Location Name  \
# ...

# %% [markdown]
# __Observation:__ The first record looks like an error (simply the parameters of the database search). I will delete this now before moving forward with other cleaning.

# %%
# Print the number of rows and columns in the runups_1985_1994 dataframe
runups_1985_1994.shape
# Out:
# (1135, 45)

# %%
# Delete a the first row by index value 0
runups_1985_1994 = runups_1985_1994.drop(labels=0, axis=0)

# %%
# Print the number of rows and columns in the runups_1985_1994 dataframe
runups_1985_1994.shape
# Out:
# (1134, 45)

# %%
# Print first 5 rows of dataframe
runups_1985_1994.head()
# Out:
#   Search Parameters    Year   Mo   Dy    Hr    Mn  Sec  \
# 1               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 2               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 3               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 4               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 5               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 1                     4.0                 1.0   2158.0                   8.0
# 2                     4.0                 1.0   2158.0                   8.0
# 3                     4.0                 1.0   2158.0                   8.0
# 4                     4.0                 1.0   2158.0                   8.0
# 5                     4.0                 1.0   2158.0                   8.0
#
#    Vol  More Info Doubtful Runup Country Area           Location Name  \
# 1  NaN        NaN              n     USA   AK  ADAK, SWEEPER COVE, AK
# ...

# %% [markdown]
# ### 2.1.2 Import Data for 1995-2004

# %%
# Import runups_1995-2004.tsv data set
runups_1995_2004 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data','runups_1995-2004.tsv'),sep='\t')

# %%
# Print first 5 rows of dataframe
runups_1995_2004.head()
# Out:
#           Search Parameters    Year   Mo    Dy    Hr    Mn   Sec  \
# 0  ["1995 <= Year >= 2004"]     NaN  NaN   NaN   NaN   NaN   NaN
# 1                       NaN  1995.0  1.0  16.0  20.0  46.0  53.6
# 2                       NaN  1995.0  1.0  16.0  20.0  46.0  53.6
# 3                       NaN  1995.0  4.0   7.0  22.0   6.0  56.8
# 4                       NaN  1995.0  4.0   7.0  22.0   6.0  56.8
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 0                     NaN                 NaN      NaN                   NaN
# 1                     4.0                 1.0   2236.0                   6.9
# 2                     4.0                 1.0   2236.0                   6.9
# 3                     4.0                 1.0   2240.0                   7.4
# 4                     4.0                 1.0   2240.0                   7.4
#
#    Vol  More Info Doubtful Runup        Country   Area  \
# ...

# %% [markdown]
# __Observation:__ The first record looks like an error (simply the parameters of the database search). I will delete this now before moving forward with other cleaning.

# %%
# Print the number of rows and columns in the runups_1995_2004 dataframe
runups_1995_2004.shape
# Out:
# (3767, 45)

# %%
# Delete a the first row by index value 0
runups_1995_2004 = runups_1995_2004.drop(labels=0, axis=0)

# %%
# Check the number of rows and columns in the runups_1995_2004 dataframe
runups_1995_2004.shape
# Out:
# (3766, 45)

# %%
# Print first 5 rows of dataframe
runups_1995_2004.head()
# Out:
#   Search Parameters    Year   Mo    Dy    Hr    Mn   Sec  \
# 1               NaN  1995.0  1.0  16.0  20.0  46.0  53.6
# 2               NaN  1995.0  1.0  16.0  20.0  46.0  53.6
# 3               NaN  1995.0  4.0   7.0  22.0   6.0  56.8
# 4               NaN  1995.0  4.0   7.0  22.0   6.0  56.8
# 5               NaN  1995.0  4.0   7.0  22.0   6.0  56.8
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 1                     4.0                 1.0   2236.0                   6.9
# 2                     4.0                 1.0   2236.0                   6.9
# 3                     4.0                 1.0   2240.0                   7.4
# 4                     4.0                 1.0   2240.0                   7.4
# 5                     4.0                 1.0   2240.0                   7.4
#
#    Vol  More Info Doubtful Runup        Country   Area  \
# 1  NaN        NaN              n          JAPAN  HYOGO
# ...

# %% [markdown]
# ### 2.1.3 Import Data for 2005-2014

# %%
# Import runups_2005-2014.tsv data set
runups_2005_2014 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data','runups_2005-2014.tsv'),sep='\t')

# %%
# Print first 5 rows of dataframe
runups_2005_2014.head()
# Out:
#           Search Parameters    Year   Mo    Dy   Hr    Mn   Sec  \
# 0  ["2005 <= Year >= 2014"]     NaN  NaN   NaN  NaN   NaN   NaN
# 1                       NaN  2005.0  1.0  19.0  6.0  11.0  36.4
# 2                       NaN  2005.0  1.0  19.0  6.0  11.0  36.4
# 3                       NaN  2005.0  1.0  19.0  6.0  11.0  36.4
# 4                       NaN  2005.0  1.0  19.0  6.0  11.0  36.4
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 0                     NaN                 NaN      NaN                   NaN
# 1                     4.0                 1.0   2466.0                   6.6
# 2                     4.0                 1.0   2466.0                   6.6
# 3                     4.0                 1.0   2466.0                   6.6
# 4                     4.0                 1.0   2466.0                   6.6
#
#    Vol  More Info Doubtful Runup Country               Area  Location Name  \
# ...

# %% [markdown]
# __Observation:__ The first record looks like an error (simply the parameters of the database search). I will delete this now before moving forward with other cleaning.

# %%
# Print the number of rows and columns in the runups_2005_2014 dataframe
runups_2005_2014.shape
# Out:
# (10416, 45)

# %%
# Delete a the first row by index value 0
runups_2005_2014 = runups_2005_2014.drop(labels=0, axis=0)

# %%
# Print the number of rows and columns in the runups_2005_2014 dataframe
runups_2005_2014.shape
# Out:
# (10415, 45)

# %%
# Print first 5 rows of dataframe
runups_2005_2014.head()
# Out:
#   Search Parameters    Year   Mo    Dy   Hr    Mn   Sec  \
# 1               NaN  2005.0  1.0  19.0  6.0  11.0  36.4
# 2               NaN  2005.0  1.0  19.0  6.0  11.0  36.4
# 3               NaN  2005.0  1.0  19.0  6.0  11.0  36.4
# 4               NaN  2005.0  1.0  19.0  6.0  11.0  36.4
# 5               NaN  2005.0  1.0  19.0  6.0  11.0  36.4
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 1                     4.0                 1.0   2466.0                   6.6
# 2                     4.0                 1.0   2466.0                   6.6
# 3                     4.0                 1.0   2466.0                   6.6
# 4                     4.0                 1.0   2466.0                   6.6
# 5                     4.0                 1.0   2466.0                   6.6
#
#    Vol  More Info Doubtful Runup Country               Area  \
# 1  NaN        NaN              n   JAPAN    BONIN IS, TOKYO
# ...

# %% [markdown]
# ### 2.1.4 Import Data for 2015-2024

# %%
# Import runups_2015-2024.tsv data set
runups_2015_2024 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data','runups_2015-2024.tsv'),sep='\t')

# %%
# Print first 5 rows of dataframe
runups_2015_2024.head()
# Out:
#           Search Parameters    Year   Mo    Dy    Hr    Mn   Sec  \
# 0  ["2015 <= Year >= 2024"]     NaN  NaN   NaN   NaN   NaN   NaN
# 1                       NaN  2015.0  2.0  16.0  23.0   6.0  28.3
# 2                       NaN  2015.0  2.0  16.0  23.0   6.0  28.3
# 3                       NaN  2015.0  2.0  16.0  23.0   6.0  28.3
# 4                       NaN  2015.0  2.0  19.0  13.0  18.0  32.8
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 0                     NaN                 NaN      NaN                   NaN
# 1                     4.0                 1.0   5580.0                   6.7
# 2                     4.0                 1.0   5580.0                   6.7
# 3                     4.0                 1.0   5580.0                   6.7
# 4                     4.0                 1.0   5582.0                   6.4
#
#    Vol  More Info Doubtful Runup  Country    Area Location Name  Latitude  \
# ...

# %% [markdown]
# __Observation:__ The first record looks like an error (simply the parameters of the database search). I will delete this now before moving forward with other cleaning.

# %%
# Print the number of rows and columns in the runups_2015_2024 dataframe
runups_2015_2024.shape
# Out:
# (4583, 45)

# %%
# Delete a the first row by index value 0
runups_2015_2024 = runups_2015_2024.drop(labels=0, axis=0)

# %%
# Print the number of rows and columns in the runups_2015_2024 dataframe
runups_2015_2024.shape
# Out:
# (4582, 45)

# %%
# Print first 5 rows of dataframe
runups_2015_2024.head()
# Out:
#   Search Parameters    Year   Mo    Dy    Hr    Mn   Sec  \
# 1               NaN  2015.0  2.0  16.0  23.0   6.0  28.3
# 2               NaN  2015.0  2.0  16.0  23.0   6.0  28.3
# 3               NaN  2015.0  2.0  16.0  23.0   6.0  28.3
# 4               NaN  2015.0  2.0  19.0  13.0  18.0  32.8
# 5               NaN  2015.0  2.0  19.0  13.0  18.0  32.8
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 1                     4.0                 1.0   5580.0                   6.7
# 2                     4.0                 1.0   5580.0                   6.7
# 3                     4.0                 1.0   5580.0                   6.7
# 4                     4.0                 1.0   5582.0                   6.4
# 5                     4.0                 1.0   5582.0                   6.4
#
#    Vol  More Info Doubtful Runup  Country    Area  Location Name  Latitude  \
# 1  NaN        NaN              n    JAPAN   IWATE         KUJIKO    40.200
# ...

# %% [markdown]
# ### 2.1.5 Merge Dataframes

# %% [markdown]
# __Note:__ I'll use pd.concat() as I want to merge vertically rather than horizontally.

# %%
frames = [runups_1985_1994, runups_1995_2004, runups_2005_2014, runups_2015_2024] # Create list of dataframes to concatonate
runups_1985_2024 = pd.concat(frames) # Concatonate and save as new dataframe

# %%
# Check that this has worked
runups_1985_2024.shape
# Out:
# (19897, 45)

# %%
# View beginning of data frame
runups_1985_2024.head()
# Out:
#   Search Parameters    Year   Mo   Dy    Hr    Mn  Sec  \
# 1               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 2               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 3               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 4               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 5               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 1                     4.0                 1.0   2158.0                   8.0
# 2                     4.0                 1.0   2158.0                   8.0
# 3                     4.0                 1.0   2158.0                   8.0
# 4                     4.0                 1.0   2158.0                   8.0
# 5                     4.0                 1.0   2158.0                   8.0
#
#    Vol  More Info Doubtful Runup Country Area           Location Name  \
# 1  NaN        NaN              n     USA   AK  ADAK, SWEEPER COVE, AK
# ...

# %%
# View end of data frame
runups_1985_2024.tail()
# Out:
#      Search Parameters    Year    Mo    Dy    Hr    Mn   Sec  \
# 4578               NaN  2024.0  12.0   5.0  18.0  44.0  21.0
# 4579               NaN  2024.0  12.0   5.0  18.0  44.0  21.0
# 4580               NaN  2024.0  12.0   5.0  18.0  44.0  21.0
# 4581               NaN  2024.0  12.0  17.0   1.0  47.0  26.0
# 4582               NaN  2024.0  12.0  17.0   1.0  47.0  26.0
#
#       Tsunami Event Validity  Tsunami Cause Code  Tsu Src  \
# 4578                     4.0                 1.0   5940.0
# 4579                     4.0                 1.0   5940.0
# 4580                     4.0                 1.0   5940.0
# 4581                     4.0                 1.0   5942.0
# 4582                     4.0                 1.0   5942.0
#
#       Earthquake Magnitude  Vol  More Info Doubtful Runup  Country Area  \
# 4578                   7.0  NaN        NaN              n      USA   CA
# 4579                   7.0  NaN        NaN              n      USA   CA
# ...

# %%
runups_reset = runups_1985_2024.reset_index(drop=True)

# %%
# View beginning of data frame
runups_1985_2024.head()
# Out:
#   Search Parameters    Year   Mo   Dy    Hr    Mn  Sec  \
# 1               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 2               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 3               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 4               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
# 5               NaN  1985.0  3.0  3.0  22.0  47.0  9.5
#
#    Tsunami Event Validity  Tsunami Cause Code  Tsu Src  Earthquake Magnitude  \
# 1                     4.0                 1.0   2158.0                   8.0
# 2                     4.0                 1.0   2158.0                   8.0
# 3                     4.0                 1.0   2158.0                   8.0
# 4                     4.0                 1.0   2158.0                   8.0
# 5                     4.0                 1.0   2158.0                   8.0
#
#    Vol  More Info Doubtful Runup Country Area           Location Name  \
# 1  NaN        NaN              n     USA   AK  ADAK, SWEEPER COVE, AK
# ...

# %% [markdown]
# ## 2.2 Earthquake Dataset

# %%
# Import earthquakes_1985-2024 dataset
earthquakes_1985_2024 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data','earthquakes_1985-2024.tsv'),sep='\t')

# %%
# Print first 5 rows of dataframe
earthquakes_1985_2024.head()
# Out:
#           Search Parameters    Year   Mo    Dy    Hr    Mn   Sec     Tsu  Vol  \
# 0  ["1985 <= Year >= 2024"]     NaN  NaN   NaN   NaN   NaN   NaN     NaN  NaN
# 1                       NaN  1985.0  1.0  26.0   3.0   6.0  57.8     NaN  NaN
# 2                       NaN  1985.0  2.0   2.0  20.0  52.0  34.2     NaN  NaN
# 3                       NaN  1985.0  3.0   3.0  22.0  47.0   9.5  2158.0  NaN
# 4                       NaN  1985.0  3.0  16.0  14.0  54.0   0.7  2159.0  NaN
#
#                                     Location Name  Latitude  Longitude  \
# 0                                             NaN       NaN        NaN
# 1     ARGENTINA:  WEST CENTRAL, MENDOZA, LA LIGUA   -33.053    -68.467
# 2                      IRAN:  S, FIRUZABAD-JAHROM    28.399     52.997
# 3  CHILE:  CENTRAL COAST, SAN ANTONIO, VALPARAISO   -33.132    -71.708
# 4                                      GUADELOUPE    17.013    -62.448
#
# ...

# %% [markdown]
# **Observation:** The first row is an error. I'll delete this now before moving forward.

# %%
# Print the number of rows and columns in the runups_1985_1994 dataframe
earthquakes_1985_2024.shape
# Out:
# (1864, 39)

# %%
# Delete a the first row by index value 0
earthquakes_1985_2024 = earthquakes_1985_2024.drop(labels=0, axis=0)

# %%
# Print the number of rows and columns in the runups_1985_1994 dataframe
earthquakes_1985_2024.shape
# Out:
# (1863, 39)

# %%
# Print first 5 rows of dataframe
earthquakes_1985_2024.head()
# Out:
#   Search Parameters    Year   Mo    Dy    Hr    Mn   Sec     Tsu  Vol  \
# 1               NaN  1985.0  1.0  26.0   3.0   6.0  57.8     NaN  NaN
# 2               NaN  1985.0  2.0   2.0  20.0  52.0  34.2     NaN  NaN
# 3               NaN  1985.0  3.0   3.0  22.0  47.0   9.5  2158.0  NaN
# 4               NaN  1985.0  3.0  16.0  14.0  54.0   0.7  2159.0  NaN
# 5               NaN  1985.0  3.0  17.0  10.0  41.0  38.4     NaN  NaN
#
#                                     Location Name  Latitude  Longitude  \
# 1     ARGENTINA:  WEST CENTRAL, MENDOZA, LA LIGUA   -33.053    -68.467
# 2                      IRAN:  S, FIRUZABAD-JAHROM    28.399     52.997
# 3  CHILE:  CENTRAL COAST, SAN ANTONIO, VALPARAISO   -33.132    -71.708
# 4                                      GUADELOUPE    17.013    -62.448
# 5                CHILE:  VALPARAISO, VINA DEL MAR   -32.663    -71.551
#
#    Focal Depth (km)  Mag  MMI Int  Deaths  Death Description  Missing  \
# ...

# %% [markdown]
# # 3.0 Data Cleaning

# %% [markdown]
# > ***Please note:***
# > As no data dictionary was avaliable to download for this dataset, I **[created one in excel](https://docs.google.com/spreadsheets/d/1tx3QDxKCmloHFD5AshxsNpjPgWo05t5A/edit?usp=drive_link&ouid=117743597182117983128&rtpof=true&sd=true)** for my own reference, using the details found by hovering over the question marks against each variable in the **[NCEI Tsunami Database](https://www.ngdc.noaa.gov/hazel/view/hazards/tsunami/runup-search)** (where the dataset was generated).
# > I will refer to the data dictionary where relevant during the cleaning process.

# %% [markdown]
# ## 3.1 Runups Dataframe

# %% [markdown]
# ### 3.1.1 Select variables of interest

# %%
# Get summary info about the DataFrame
runups_1985_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19897 entries, 1 to 4582
# Data columns (total 45 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Search Parameters             0 non-null      object
#  1   Year                          19897 non-null  float64
#  2   Mo                            19897 non-null  float64
#  3   Dy                            19896 non-null  float64
#  4   Hr                            19699 non-null  float64
#  5   Mn                            19693 non-null  float64
#  6   Sec                           19120 non-null  float64
#  7   Tsunami Event Validity        19897 non-null  float64
#  8   Tsunami Cause Code            19897 non-null  float64
#  9   Tsu Src                       19897 non-null  float64
#  10  Earthquake Magnitude          18332 non-null  float64
#  11  Vol                           1310 non-null   float64
# ...

# %%
# Remove columns with 0 non-null data from DataFrame
runups = runups_1985_2024.drop(['Search Parameters','More Info'], axis=1)

# %%
# Check this worked
runups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19897 entries, 1 to 4582
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          19897 non-null  float64
#  1   Mo                            19897 non-null  float64
#  2   Dy                            19896 non-null  float64
#  3   Hr                            19699 non-null  float64
#  4   Mn                            19693 non-null  float64
#  5   Sec                           19120 non-null  float64
#  6   Tsunami Event Validity        19897 non-null  float64
#  7   Tsunami Cause Code            19897 non-null  float64
#  8   Tsu Src                       19897 non-null  float64
#  9   Earthquake Magnitude          18332 non-null  float64
#  10  Vol                           1310 non-null   float64
#  11  Doubtful Runup                19897 non-null  object
# ...

# %%
# Get statistical summary of the numeric columns
runups_1985_2024.describe()
# Out:
#                Year            Mo            Dy            Hr            Mn  \
# count  19897.000000  19897.000000  19896.000000  19699.000000  19693.000000
# mean    2009.670151      6.080967     15.892994      8.794101     39.863302
# std        7.524067      3.826876      8.135394      6.940615     15.911171
# min     1985.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2005.000000      3.000000     11.000000      5.000000     34.000000
# 50%     2011.000000      4.000000     14.000000      5.000000     46.000000
# 75%     2013.000000      9.000000     25.000000     14.000000     49.000000
# max     2024.000000     12.000000     31.000000     23.000000     59.000000
#
#                 Sec  Tsunami Event Validity  Tsunami Cause Code       Tsu Src  \
# count  19120.000000            19897.000000        19897.000000  19897.000000
# mean      29.002123                3.985123            1.540685   4532.135347
# ...

# %%
# Check for missing values across all columns
runups.isnull().sum()
# Out:
# Year                                0
# Mo                                  0
# Dy                                  1
# Hr                                198
# Mn                                204
# Sec                               777
# Tsunami Event Validity              0
# Tsunami Cause Code                  0
# Tsu Src                             0
# Earthquake Magnitude             1565
# Vol                             18587
# Doubtful Runup                      0
# Country                             1
# Area                             4333
# Location Name                       2
# Latitude                          107
# Longitude                         107
# Distance From Source (km)         207
# Initial Wave Arrival Dy         16659
# Initial Wave Arrival Hr         16688
# Initial Wave Arrival Min        16700
# Travel Hours                    17671
# Travel Minutes                  17605
# Max Wave Arrival Day            17403
# Max Wave Arrival Hr             17403
# ...

# %%
# Check shape of data frame again for reference
runups.shape
# Out:
# (19897, 43)

# %%
# Check what 5% of the data set is (don't want to drop more) 
19897*.05
# Out:
# 994.85

# %% [markdown]
# __Observation:__ Any columns where there is more than 5% of the dataframe (i.e. 995) records missing should be removed. Unforunately, there are a few important variables in my dataset that are missing more than 5% of their values. These are _Earthquake Magnitude_ and _Max Water Height_. Additionally, I'd like to keep _Travel Hours_ and _Travel Minutes_ but these are less important if I have to drop them.
#
# I will drop all other columns that exceed this number __except__ for these four variables that I'm interested in analysing.

# %%
# Drop columns with large number of missing values and/or are of no interest.
runups = runups.drop(['Area','Initial Wave Arrival Dy','Initial Wave Arrival Hr',
                       'Initial Wave Arrival Min','Travel Hours','Travel Minutes','Max Wave Arrival Day',
                       'Max Wave Arrival Hr','Max Wave Arrival Min','Period','First Motion','Deaths','Death Description',
                       'Missing','Missing Description','Injuries','Injuries Description','Damage $Mil','Damage Description',
                       'Houses Destroyed','Houses Destroyed Description','Houses Damaged','Houses Damaged Description','Vol',
                       'Max Inundation Distance (m)'], axis=1)

# %%
# Check for missing values from new dataframe to check the column drop worked
runups.isnull().sum()
# Out:
# Year                            0
# Mo                              0
# Dy                              1
# Hr                            198
# Mn                            204
# Sec                           777
# Tsunami Event Validity          0
# Tsunami Cause Code              0
# Tsu Src                         0
# Earthquake Magnitude         1565
# Doubtful Runup                  0
# Country                         1
# Location Name                   2
# Latitude                      107
# Longitude                     107
# Distance From Source (km)     207
# Max Water Height (m)         1101
# Measurement Type               39
# dtype: int64

# %% [markdown]
# __Observation:__ After consulting my data dictionary, I don't think Measurment Type will be useful to my analysis, so this variable will also be dropped.

# %%
# Drop Measurement Type from data frame
runups = runups.drop(['Measurement Type'], axis=1)

# %%
# Check for missing values from new DataFrame to check the column drop worked
runups.isnull().sum()
# Out:
# Year                            0
# Mo                              0
# Dy                              1
# Hr                            198
# Mn                            204
# Sec                           777
# Tsunami Event Validity          0
# Tsunami Cause Code              0
# Tsu Src                         0
# Earthquake Magnitude         1565
# Doubtful Runup                  0
# Country                         1
# Location Name                   2
# Latitude                      107
# Longitude                     107
# Distance From Source (km)     207
# Max Water Height (m)         1101
# dtype: int64

# %%
# Rename column names for clarity
runups.rename(columns = {'Mo' : 'Month','Dy':'Day','Hr':'Hour','Mn':'Minute','Sec':'Second','Tsu Src':'Tsunami Event ID'}, inplace = True)

# %%
# Print column names
runups.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Hour', 'Minute', 'Second',
#        'Tsunami Event Validity', 'Tsunami Cause Code', 'Tsunami Event ID',
#        'Earthquake Magnitude', 'Doubtful Runup', 'Country', 'Location Name',
#        'Latitude', 'Longitude', 'Distance From Source (km)',
#        'Max Water Height (m)'],
#       dtype='object')

# %%
# Change the order of columns
runups = runups[['Tsunami Event ID', 'Year', 'Month', 'Day', 'Hour', 'Minute', 'Second',
       'Tsunami Event Validity', 'Tsunami Cause Code',
       'Earthquake Magnitude', 'Doubtful Runup', 'Country', 'Location Name',
       'Latitude', 'Longitude', 'Distance From Source (km)',
       'Max Water Height (m)']]

# %%
runups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19897 entries, 1 to 4582
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Tsunami Event ID           19897 non-null  float64
#  1   Year                       19897 non-null  float64
#  2   Month                      19897 non-null  float64
#  3   Day                        19896 non-null  float64
#  4   Hour                       19699 non-null  float64
#  5   Minute                     19693 non-null  float64
#  6   Second                     19120 non-null  float64
#  7   Tsunami Event Validity     19897 non-null  float64
#  8   Tsunami Cause Code         19897 non-null  float64
#  9   Earthquake Magnitude       18332 non-null  float64
#  10  Doubtful Runup             19897 non-null  object
#  11  Country                    19896 non-null  object
#  12  Location Name              19895 non-null  object
# ...

# %% [markdown]
# ### 3.1.2 Remove duplicates

# %%
# Find duplicates
dups = runups[runups.duplicated(keep=False)]
dups.shape # Rows, Columns
# Out:
# (120, 17)

# %%
# Export dups to csv for further inspection
dups.to_csv(os.path.join(path, '02 Data','Prepared Data','dups.csv'))

# %% [markdown]
# **Note:** I have inspected the duplicates and they appear to be genuine duplicates. These will be removed from the dataframe.

# %%
# Check shape of data frame before dropping duplicates
runups.shape
# Out:
# (19897, 17)

# %%
# Remove duplicate values.
runups = runups.drop_duplicates()
runups.shape # Check shape after drop
# Out:
# (19827, 17)

# %% [markdown]
# ### 3.1.3 Check for mixed data types

# %%
# Check for mixed data types
for col in runups.columns.tolist():
      weird = (runups[[col]].map(type) != runups[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (runups[weird]) > 0:
        print (col)
# Out:
# Country
# Location Name

# %%
# Recast as Country and Location Name as string
runups['Country'] = runups['Country'].astype(str)
runups['Location Name'] = runups['Location Name'].astype(str)

# %%
# Check data types
runups.dtypes
# Out:
# Tsunami Event ID             float64
# Year                         float64
# Month                        float64
# Day                          float64
# Hour                         float64
# Minute                       float64
# Second                       float64
# Tsunami Event Validity       float64
# Tsunami Cause Code           float64
# Earthquake Magnitude         float64
# Doubtful Runup                object
# Country                       object
# Location Name                 object
# Latitude                     float64
# Longitude                    float64
# Distance From Source (km)    float64
# Max Water Height (m)         float64
# dtype: object

# %%
# View sample of data
runups.head()
# Out:
#    Tsunami Event ID    Year  Month  Day  Hour  Minute  Second  \
# 1            2158.0  1985.0    3.0  3.0  22.0    47.0     9.5
# 2            2158.0  1985.0    3.0  3.0  22.0    47.0     9.5
# 3            2158.0  1985.0    3.0  3.0  22.0    47.0     9.5
# 4            2158.0  1985.0    3.0  3.0  22.0    47.0     9.5
# 5            2158.0  1985.0    3.0  3.0  22.0    47.0     9.5
#
#    Tsunami Event Validity  Tsunami Cause Code  Earthquake Magnitude  \
# 1                     4.0                 1.0                   8.0
# 2                     4.0                 1.0                   8.0
# 3                     4.0                 1.0                   8.0
# 4                     4.0                 1.0                   8.0
# 5                     4.0                 1.0                   8.0
#
#   Doubtful Runup Country           Location Name   Latitude   Longitude  \
# 1              n     USA  ADAK, SWEEPER COVE, AK  51.863000 -176.632000
# ...

# %% [markdown]
# **Note:** Will recast discrete variables (Year, Month, Day, Hour, Minute, Tsunami Event ID, Tsunami Event Validity and Tsunami Cause Code) as integer data type.

# %%
# Checking for null values in target variables
runups.isnull().sum()
# Out:
# Tsunami Event ID                0
# Year                            0
# Month                           0
# Day                             1
# Hour                          198
# Minute                        204
# Second                        777
# Tsunami Event Validity          0
# Tsunami Cause Code              0
# Earthquake Magnitude         1565
# Doubtful Runup                  0
# Country                         0
# Location Name                   0
# Latitude                      107
# Longitude                     107
# Distance From Source (km)     207
# Max Water Height (m)         1101
# dtype: int64

# %% [markdown]
# **Note:** I cannot recast _Day_, _Hour_ or _Minute_ columns as they have missing value present. Will recast each of these variables after I have taken care of their missing values.

# %%
# Recast as discrete variables 
#('Year', 'Month', 'Day', 'Hour', 'Minute', 'Tsunami Event ID', 'Tsunami Event Validity' and 'Tsunami Cause Code')
runups['Year'] = runups['Year'].astype(int)
runups['Month'] = runups['Month'].astype(int)
runups['Tsunami Event ID'] = runups['Tsunami Event ID'].astype(int)
runups['Tsunami Event Validity'] = runups['Tsunami Event Validity'].astype(int)
runups['Tsunami Cause Code'] = runups['Tsunami Cause Code'].astype(int)

# %%
# Check data types have updated.
runups.dtypes
# Out:
# Tsunami Event ID               int64
# Year                           int64
# Month                          int64
# Day                          float64
# Hour                         float64
# Minute                       float64
# Second                       float64
# Tsunami Event Validity         int64
# Tsunami Cause Code             int64
# Earthquake Magnitude         float64
# Doubtful Runup                object
# Country                       object
# Location Name                 object
# Latitude                     float64
# Longitude                    float64
# Distance From Source (km)    float64
# Max Water Height (m)         float64
# dtype: object

# %%
# View sample of data
runups.head()
# Out:
#    Tsunami Event ID  Year  Month  Day  Hour  Minute  Second  \
# 1              2158  1985      3  3.0  22.0    47.0     9.5
# 2              2158  1985      3  3.0  22.0    47.0     9.5
# 3              2158  1985      3  3.0  22.0    47.0     9.5
# 4              2158  1985      3  3.0  22.0    47.0     9.5
# 5              2158  1985      3  3.0  22.0    47.0     9.5
#
#    Tsunami Event Validity  Tsunami Cause Code  Earthquake Magnitude  \
# 1                       4                   1                   8.0
# 2                       4                   1                   8.0
# 3                       4                   1                   8.0
# 4                       4                   1                   8.0
# 5                       4                   1                   8.0
#
#   Doubtful Runup Country           Location Name   Latitude   Longitude  \
# 1              n     USA  ADAK, SWEEPER COVE, AK  51.863000 -176.632000
# ...

# %% [markdown]
# ### 3.1.4 Filter dataset

# %% [markdown]
# > **Filtering for relevant events**
# > After reviewing the data dictionary further, I noticed that there are a few variables that we can already use to filter out records that are not relevant to our analysis. These variables are _Tusnami Event Validity_, _Tsunami Cause Code_ and _Doubtful Runup_.

# %% [markdown]
# #### 3.1.4.1 Tsunami Event Validity

# %% [markdown]
# Using the below definitions of the _Tsunami Event Validity_ codes, I can see that any runups with a value other than **4** is not of interest to my analysis. I'll filter my dataset accordingly.
#
# | Code | Description |
# | --- | --- |
# | -1 | erroneous entry |
# | 0	| event that only caused a seiche |
# | 1	| very doubtful tsunami |
# | 2	| questionable tsunami |
# | 3	| probable tsunami |
# | 4	| definite tsunami |

# %%
# Check frequency table for Tsunami Event Validity
runups['Tsunami Event Validity'].value_counts()
# Out:
# Tsunami Event Validity
#  4    19631
#  3      139
#  2       28
#  1       21
# -1        6
#  0        2
# Name: count, dtype: int64

# %%
# Check shape of dataframe
runups.shape
# Out:
# (19827, 17)

# %%
# Filter dataframe to only show records with a Tsunami Event Validity of 3 or 4
runups = runups[runups['Tsunami Event Validity'].isin([4])]

# %%
# Check shape of dataframe
runups.shape
# Out:
# (19631, 17)

# %%
# Check frequency table for Tsnuami Event Validity
runups['Tsunami Event Validity'].value_counts()
# Out:
# Tsunami Event Validity
# 4    19631
# Name: count, dtype: int64

# %% [markdown]
# #### 3.1.4.2 Tsunami Cause Code

# %% [markdown]
# I already know I'm missing a large number of _Earthquake Magnitude_ values. Using the below definitions of the _Tsunami Cause Code_ codes, it will be interesting to see if the missing values are associated with causes that aren't an Earthquake.
#
# | Code | Description |
# | --- | --- |
# | 0	| Unknown |
# | 1	| Earthquake |
# | 2	| Questionable Earthquake |
# | 3	| Earthquake and Landslide |
# | 4	| Volcano and Earthquake |
# | 5	| Volcano, Earthquake, and Landslide |
# | 6	| Volcano |
# | 7	| Volcano and Landslide |
# | 8	| Landslide |
# | 9	| Meteorological |
# | 10 | Explosion |
# | 11 | Astronomical Tide |

# %%
# Create subset of missing values from Earthquake Magnitude
nan_earthquake = runups[runups['Earthquake Magnitude'].isnull()]

# %%
# Create Frequency Table for Tsunami Cause Code (where Earthquake Magnitude is missing)
nan_earthquake.value_counts('Tsunami Cause Code')
# Out:
# Tsunami Cause Code
# 6    811
# 7    452
# 9    106
# 8    102
# 0     16
# Name: count, dtype: int64

# %% [markdown]
# **Observation** As suspected, all missing _Earthquake Magnitude_ values are associated with Tsunami Events that were cause by other than a Tsunami. I'll create a flag column for this so that non-earthquake events can be filtered out when analysing this variable.

# %%
# Check DataFrame shape
runups.shape
# Out:
# (19631, 17)

# %%
# Create Flag Earthquake
runups.loc[runups['Tsunami Cause Code'].isin([1, 2, 3, 4, 5, 9, 10, 11]), 'Flag Earthquake'] = 'Yes'
runups.loc[runups['Tsunami Cause Code'].isin([0, 6, 7, 8]), 'Flag Earthquake'] = 'No'

# %%
# Check columns
runups.columns
# Out:
# Index(['Tsunami Event ID', 'Year', 'Month', 'Day', 'Hour', 'Minute', 'Second',
#        'Tsunami Event Validity', 'Tsunami Cause Code', 'Earthquake Magnitude',
#        'Doubtful Runup', 'Country', 'Location Name', 'Latitude', 'Longitude',
#        'Distance From Source (km)', 'Max Water Height (m)', 'Flag Earthquake'],
#       dtype='object')

# %%
# Check DataFrame shape
runups.shape
# Out:
# (19631, 18)

# %%
# Create Frequency table for Flag Earthquake
runups.value_counts('Flag Earthquake')
# Out:
# Flag Earthquake
# Yes    18250
# No      1381
# Name: count, dtype: int64

# %% [markdown]
# #### 3.1.4.3 Doubtful Runup

# %% [markdown]
# Using the below definitions from the data dictionary for the _Doubtful Runup_ variable, I can see that I only want to keep events with a code of **n**.
#
# | Code | Description |
# | --- | --- |
# | n	| Runup entry was not doubtful |
# | y	| Runup entry was doubtful |
# | m	| The waves likely had a meteorologic source, and thus were not true tsunami waves |
# | a	| The waves likely were generated by atmospheric waves from a volcanic source |

# %%
# Check value counts for Doubtful Runup
runups.value_counts('Doubtful Runup')
# Out:
# Doubtful Runup
# n    18789
# a      649
# m      106
# y       87
# Name: count, dtype: int64

# %%
# Check DataFrame shape
runups.shape
# Out:
# (19631, 18)

# %%
# Filter rows where 'Doubtful Runup' is either 'n'
runups = runups[(runups['Doubtful Runup'] == 'n')]

# %%
# Check value counts
runups.value_counts('Doubtful Runup')
# Out:
# Doubtful Runup
# n    18789
# Name: count, dtype: int64

# %% [markdown]
# **Note:** Now that I only have one value for this variable, it is no longer worthwhile keeping and will be dropped from the data frame.

# %%
# Check DataFrame shape
runups.shape
# Out:
# (18789, 18)

# %%
# Drop 'Doubtful Runup' variable
runups = runups.drop(['Doubtful Runup'], axis=1)

# %%
# Check DataFrame shape
runups.columns
# Out:
# Index(['Tsunami Event ID', 'Year', 'Month', 'Day', 'Hour', 'Minute', 'Second',
#        'Tsunami Event Validity', 'Tsunami Cause Code', 'Earthquake Magnitude',
#        'Country', 'Location Name', 'Latitude', 'Longitude',
#        'Distance From Source (km)', 'Max Water Height (m)', 'Flag Earthquake'],
#       dtype='object')

# %% [markdown]
# ### 3.1.5 Handle missing values

# %%
# Check for missing values from dataframe
runups.isnull().sum()
# Out:
# Tsunami Event ID               0
# Year                           0
# Month                          0
# Day                            0
# Hour                          68
# Minute                        74
# Second                       598
# Tsunami Event Validity         0
# Tsunami Cause Code             0
# Earthquake Magnitude         728
# Country                        0
# Location Name                  0
# Latitude                     103
# Longitude                    103
# Distance From Source (km)    103
# Max Water Height (m)         983
# Flag Earthquake                0
# dtype: int64

# %% [markdown]
# **Note:** The main variable of concern here with missing values is _Max Water Height (m)_. I'll investigate this first before investigating any others.
#
# _Please note:_ Although _Earthquake Magnitude_ has a lot of missing values, we can handle this with the previously create flag, 'Flag Earthquake'.

# %% [markdown]
# #### 3.1.5.1 Max Water Height

# %%
# Check shape of dataframe
runups.shape
# Out:
# (18789, 17)

# %%
18906 * .05
# Out:
# 945.3000000000001

# %% [markdown]
# **Note:** It would probably be okay to simply drop the missing Max Water Height (m) values, but let's explore a little more to see if there is a simple answer for imputation.

# %%
# Count non-NaN values per Tsunami Event ID
non_na_counts = runups.groupby('Tsunami Event ID')['Max Water Height (m)'].count()

# Get Event IDs where the count is 0 (i.e., all values are NaN)
no_wave_height_ids = non_na_counts[non_na_counts == 0].index

# Filter the original DataFrame for all records with these Event IDs
no_wave_height_runups = runups[runups['Tsunami Event ID'].isin(no_wave_height_ids)]

no_wave_height_runups['Tsunami Event ID'].nunique()
# Out:
# 13

# %%
# Count number of Tsunami's in the dataframe
runups['Tsunami Event ID'].nunique()
# Out:
# 399

# %%
# Check what percentage this is of the total tsunami's in dataset
13/453
# Out:
# 0.02869757174392936

# %%
# Identify Tsunami Event IDs with missing 'Max Water Height (m)'
event_ids_with_missing = runups[runups['Max Water Height (m)'].isna()]['Tsunami Event ID'].unique()

# Filter the original DataFrame for all records with those Event IDs
filtered_runups = runups[runups['Tsunami Event ID'].isin(event_ids_with_missing)]

# Export the filtered DataFrame to a CSV file
filtered_runups.to_csv(os.path.join(path,'02 Data','Prepared Data','filtered_runups.csv'), index=False)

# %% [markdown]
# **Note:** After inspecting this subset, I noticed the main characteristic of missing _Max Water Height (m)_ records is their location; they are largely in either cities/islands that are:
# - unihabited
# - have no recorded population findable online
# - small population (i.e. < 50,000)
#
# Removing these records could potentially introduce bias into the dataset, in that the impact on small communities could be lost from the analysis. However, for simplicity, I will remove these records as they represent just over 5% of the dataframe.

# %%
# Shape of dataframe
runups.shape
# Out:
# (18789, 17)

# %%
# Drop missing values from 'Max Water Height (m)'
runups = runups.dropna(subset=['Max Water Height (m)'])

# %%
# Shape of dataframe
runups.shape
# Out:
# (17806, 17)

# %%
# Check for missing values from dataframe
runups.isnull().sum()
# Out:
# Tsunami Event ID               0
# Year                           0
# Month                          0
# Day                            0
# Hour                          58
# Minute                        64
# Second                       549
# Tsunami Event Validity         0
# Tsunami Cause Code             0
# Earthquake Magnitude         666
# Country                        0
# Location Name                  0
# Latitude                      66
# Longitude                     66
# Distance From Source (km)     66
# Max Water Height (m)           0
# Flag Earthquake                0
# dtype: int64

# %% [markdown]
# #### 3.1.5.2 Hour, Minute and Second

# %% [markdown]
# **Note:** _Hour_, _Minute_ and _Second_ were kept as variables as it was thought they might help resolve the missing values for Max Water Height (m). As they are no longer needed, these will be dropped.

# %%
# Drop columns with large number of missing values and/or are of no interest.
runups = runups.drop(['Hour','Minute','Second'], axis=1)

# %%
# Check for missing values from dataframe
runups.isnull().sum()
# Out:
# Tsunami Event ID               0
# Year                           0
# Month                          0
# Day                            0
# Tsunami Event Validity         0
# Tsunami Cause Code             0
# Earthquake Magnitude         666
# Country                        0
# Location Name                  0
# Latitude                      66
# Longitude                     66
# Distance From Source (km)     66
# Max Water Height (m)           0
# Flag Earthquake                0
# dtype: int64

# %%
# Combine year, month, and day into a single datetime column
runups['date'] = pd.to_datetime(runups[['Year', 'Month', 'Day']])

# Drop the original year, month, and day columns to clean up
runups = runups.drop(columns=['Year', 'Month', 'Day'])

# Check the result
runups.head()
# Out:
#    Tsunami Event ID  Tsunami Event Validity  Tsunami Cause Code  \
# 1              2158                       4                   1
# 3              2158                       4                   1
# 4              2158                       4                   1
# 6              2158                       4                   1
# 7              2158                       4                   1
#
#    Earthquake Magnitude  Country           Location Name  Latitude  Longitude  \
# 1                   8.0      USA  ADAK, SWEEPER COVE, AK   51.8630  -176.6320
# 3                   8.0      USA          SAND POINT, AK   55.3370  -160.5020
# 4                   8.0      USA              SEWARD, AK   60.1190  -149.4270
# 6                   8.0  ECUADOR               GUAYAQUIL   -2.1833   -79.8833
# 7                   8.0      USA        HILO, HAWAII, HI   19.7303  -155.0553
#
#    Distance From Source (km)  Max Water Height (m) Flag Earthquake       date
# ...

# %%
# Reorder columns so that 'date' is the first column
runups = runups[['date', 'Tsunami Event ID', 'Tsunami Event Validity', 'Earthquake Magnitude','Country','Location Name',
                 'Latitude','Longitude','Distance From Source (km)','Max Water Height (m)','Flag Earthquake']]

runups.head()
# Out:
#         date  Tsunami Event ID  Tsunami Event Validity  Earthquake Magnitude  \
# 1 1985-03-03              2158                       4                   8.0
# 3 1985-03-03              2158                       4                   8.0
# 4 1985-03-03              2158                       4                   8.0
# 6 1985-03-03              2158                       4                   8.0
# 7 1985-03-03              2158                       4                   8.0
#
#    Country           Location Name  Latitude  Longitude  \
# 1      USA  ADAK, SWEEPER COVE, AK   51.8630  -176.6320
# 3      USA          SAND POINT, AK   55.3370  -160.5020
# 4      USA              SEWARD, AK   60.1190  -149.4270
# 6  ECUADOR               GUAYAQUIL   -2.1833   -79.8833
# 7      USA        HILO, HAWAII, HI   19.7303  -155.0553
#
#    Distance From Source (km)  Max Water Height (m) Flag Earthquake
# 1               13805.592696                  0.05             Yes
# ...

# %% [markdown]
# #### 3.1.5.3 Latitude and Longitude

# %%
nan_lat_long = runups[runups['Latitude'].isnull() == True]

# %%
nan_lat_long.to_csv(os.path.join(path,'02 Data','Prepared Data','nan_lat_long.csv'), index=False)

# %% [markdown]
# **Notes:** After inspecting the dataset can see that records have numbers included after the location (i.e. PANTAI LATO-2). It is unclear what this represents. Other records represent the _whole_ country, rather than a specific location (hence the lack of lon/lat coordinates). These are likely duplicated from a specific location measure within the dataset for a tsunami event.

# %%
# Drop missing 'Latitude' and 'Longitude' values
runups = runups.dropna(subset=['Latitude'])

# %%
# Check for missing values from dataframe
runups.isnull().sum()
# Out:
# date                           0
# Tsunami Event ID               0
# Tsunami Event Validity         0
# Earthquake Magnitude         664
# Country                        0
# Location Name                  0
# Latitude                       0
# Longitude                      0
# Distance From Source (km)      0
# Max Water Height (m)           0
# Flag Earthquake                0
# dtype: int64

# %% [markdown]
# #### 3.1.5.4 Earthquake Magnitude

# %% [markdown]
# I've decided that I only want to analyse runups from Tsunami's associated with an earthquake. This is the bulk of the dataset and will help improve the focus of my analysis.

# %%
# Drop missing 'Latitude' and 'Longitude' values
runups = runups.dropna(subset=['Earthquake Magnitude'])

# %%
# Check for missing values from dataframe
runups.isnull().sum()
# Out:
# date                         0
# Tsunami Event ID             0
# Tsunami Event Validity       0
# Earthquake Magnitude         0
# Country                      0
# Location Name                0
# Latitude                     0
# Longitude                    0
# Distance From Source (km)    0
# Max Water Height (m)         0
# Flag Earthquake              0
# dtype: int64

# %%
runups['Tsunami Event Validity'].value_counts()
# Out:
# Tsunami Event Validity
# 4    17076
# Name: count, dtype: int64

# %%
# Drop columns that are no longer needed
runups = runups.drop(['Flag Earthquake','Tsunami Event Validity'], axis=1)

# %%
# Check for missing values from dataframe
runups.isnull().sum()
# Out:
# date                         0
# Tsunami Event ID             0
# Earthquake Magnitude         0
# Country                      0
# Location Name                0
# Latitude                     0
# Longitude                    0
# Distance From Source (km)    0
# Max Water Height (m)         0
# dtype: int64

# %%
# Rename all variables to avoid issues later with spaces
runups.rename(columns = {'Tsunami Event ID' : 'tsunami_event_id','Year':'year','Month':'month','Day':'day','Tsunami Cause Code':'tsunami_cause','Earthquake Magnitude':'earthquake_magnitude','Country':'country','Location Name':'location','Latitude':'latitude','Longitude':'longitude','Distance From Source (km)':'distance_source_km','Max Water Height (m)':'max_water_height_m'}, inplace = True)

# %%
runups.columns
# Out:
# Index(['date', 'tsunami_event_id', 'earthquake_magnitude', 'country',
#        'location', 'latitude', 'longitude', 'distance_source_km',
#        'max_water_height_m'],
#       dtype='object')

# %% [markdown]
# ## 3.2 Aggregate Tsunami Dataframe

# %%
# Group by tsunami_event_id and perform the aggregations
tsunamis = runups.groupby('tsunami_event_id').agg(
    date=('date', 'first'),
    unique_countries_count=('country', 'nunique'),  # Count of unique countries
    countries=('country', lambda x: ', '.join(x.unique())),  # List of all unique countries
    earthquake_magnitude=('earthquake_magnitude', 'max'),  # Maximum magnitude per tsunami event
    max_water_height=('max_water_height_m', 'max'),  # Max water height recorded
    min_distance=('distance_source_km', 'min'),  # Min distance recorded per tsunami
    max_distance=('distance_source_km', 'max'),  # Max distance recorded per tsunami
    runup_count=('tsunami_event_id', 'size')  # Count of records for each tsunami event
).reset_index()

# Display the aggregated dataframe
tsunamis
# Out:
#      tsunami_event_id       date  unique_countries_count  \
# 0                2158 1985-03-03                       7
# 1                2159 1985-03-16                       1
# 2                2161 1985-07-03                       1
# 3                2162 1985-09-19                       8
# 4                2163 1985-09-21                       2
# ..                ...        ...                     ...
# 338              5927 1994-09-17                       1
# 339              5931 2011-03-09                       1
# 340              5938 2024-09-23                       1
# 341              5940 2024-12-05                       1
# 342              5942 2024-12-17                       1
#
#                                              countries  earthquake_magnitude  \
# 0    USA, ECUADOR, JAPAN, CHINA, FRENCH POLYNESIA, ...                   8.0
# 1                        GUADELOUPE (FRENCH TERRITORY)                   6.4
# ...

# %% [markdown]
# ## 3.3 Earthquake Dataframe

# %% [markdown]
# ### 3.3.1 Select variables of interest

# %%
# Get summary info about the DataFrame
earthquakes_1985_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1863 entries, 1 to 1863
# Data columns (total 39 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Search Parameters                   0 non-null      object
#  1   Year                                1863 non-null   float64
#  2   Mo                                  1863 non-null   float64
#  3   Dy                                  1863 non-null   float64
#  4   Hr                                  1862 non-null   float64
#  5   Mn                                  1861 non-null   float64
#  6   Sec                                 1858 non-null   float64
#  7   Tsu                                 432 non-null    float64
#  8   Vol                                 17 non-null     float64
#  9   Location Name                       1863 non-null   object
#  10  Latitude                            1863 non-null   float64
# ...

# %%
earthquakes_1985_2024.shape
# Out:
# (1863, 39)

# %%
# Remove columns with 0 non-null data from DataFrame
earthquakes = earthquakes_1985_2024.drop(['Search Parameters'], axis=1)

# %%
earthquakes.shape
# Out:
# (1863, 38)

# %%
# Check this worked
earthquakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1863 entries, 1 to 1863
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                1863 non-null   float64
#  1   Mo                                  1863 non-null   float64
#  2   Dy                                  1863 non-null   float64
#  3   Hr                                  1862 non-null   float64
#  4   Mn                                  1861 non-null   float64
#  5   Sec                                 1858 non-null   float64
#  6   Tsu                                 432 non-null    float64
#  7   Vol                                 17 non-null     float64
#  8   Location Name                       1863 non-null   object
#  9   Latitude                            1863 non-null   float64
#  10  Longitude                           1863 non-null   float64
# ...

# %%
# Get statistical summary of the numeric columns
earthquakes.describe()
# Out:
#               Year           Mo           Dy           Hr           Mn  \
# count  1863.000000  1863.000000  1863.000000  1862.000000  1861.000000
# mean   2006.129361     6.525497    15.548578    11.360365    29.382053
# std      10.504457     3.441434     8.694151     7.066552    17.543239
# min    1985.000000     1.000000     1.000000     0.000000     0.000000
# 25%    1999.000000     4.000000     8.000000     5.000000    14.000000
# 50%    2007.000000     7.000000    16.000000    11.000000    29.000000
# 75%    2015.000000    10.000000    23.000000    18.000000    45.000000
# max    2024.000000    12.000000    31.000000    23.000000    59.000000
#
#                Sec          Tsu          Vol     Latitude    Longitude  \
# count  1858.000000   432.000000    17.000000  1863.000000  1863.000000
# mean     29.883746  4254.256944  6660.176471    17.861053    48.660716
# std      17.299643  1579.681755  1171.386744    24.192882    90.309229
# ...

# %%
# Count null values in column 'Tsu'
null_count = earthquakes['Tsu'].isnull().sum()
null_count
# Out:
# 1431

# %%
# Filter to include only records with a related Tsunami event
earthquakes = earthquakes[earthquakes['Tsu'].notnull()]

# %%
earthquakes.shape
# Out:
# (432, 38)

# %%
earthquakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 432 entries, 3 to 1863
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                432 non-null    float64
#  1   Mo                                  432 non-null    float64
#  2   Dy                                  432 non-null    float64
#  3   Hr                                  432 non-null    float64
#  4   Mn                                  431 non-null    float64
#  5   Sec                                 430 non-null    float64
#  6   Tsu                                 432 non-null    float64
#  7   Vol                                 11 non-null     float64
#  8   Location Name                       432 non-null    object
#  9   Latitude                            432 non-null    float64
#  10  Longitude                           432 non-null    float64
# ...

# %%
# Check what 95% of the dataframe is
.95*432
# Out:
# 410.4

# %%
# Drop all columns with less than 410 (i.e. missing more than 5% of the dataframe)
earthquakes = earthquakes.drop(['Vol','MMI Int','Deaths','Missing','Missing Description','Injuries','Injuries Description',
                               'Damage ($Mil)','Damage Description','Houses Destroyed','Houses Destroyed Description',
                               'Houses Damaged','Houses Damaged Description','Total Deaths','Total Death Description',
                               'Total Missing','Total Missing Description','Total Injuries','Total Injuries Description',
                               'Total Damage ($Mil)','Total Damage Description','Total Houses Destroyed','Death Description',
                               'Total Houses Destroyed Description','Total Houses Damaged','Total Houses Damaged Description'], axis=1)

# %%
earthquakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 432 entries, 3 to 1863
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              432 non-null    float64
#  1   Mo                432 non-null    float64
#  2   Dy                432 non-null    float64
#  3   Hr                432 non-null    float64
#  4   Mn                431 non-null    float64
#  5   Sec               430 non-null    float64
#  6   Tsu               432 non-null    float64
#  7   Location Name     432 non-null    object
#  8   Latitude          432 non-null    float64
#  9   Longitude         432 non-null    float64
#  10  Focal Depth (km)  431 non-null    float64
#  11  Mag               431 non-null    float64
# dtypes: float64(11), object(1)
# memory usage: 43.9+ KB

# %%
# Rename column names for clarity
earthquakes.rename(columns = {'Year':'year', 'Mo':'month','Dy':'day','Hr':'hour','Mn':'minute','Sec':'second','Tsu':'tsunami_event_id','Mag':'earthquake_magnitude'}, inplace = True)

# %%
earthquakes.columns
# Out:
# Index(['year', 'month', 'day', 'hour', 'minute', 'second', 'tsunami_event_id',
#        'Location Name', 'Latitude', 'Longitude', 'Focal Depth (km)',
#        'earthquake_magnitude'],
#       dtype='object')

# %% [markdown]
# ### 3.3.2 Remove duplicates

# %%
# Find duplicates
dups = earthquakes[earthquakes.duplicated(keep=False)]
dups.shape # Rows, Columns
# Out:
# (0, 12)

# %% [markdown]
# No duplicates.

# %% [markdown]
# ### 3.3.3 Check for mixed data types

# %%
# Check for mixed data types
for col in earthquakes.columns.tolist():
      weird = (earthquakes[[col]].map(type) != earthquakes[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (earthquakes[weird]) > 0:
        print (col)

# %% [markdown]
# No mixed data types.

# %%
earthquakes.head()
# Out:
#       year  month   day  hour  minute  second  tsunami_event_id  \
# 3   1985.0    3.0   3.0  22.0    47.0     9.5            2158.0
# 4   1985.0    3.0  16.0  14.0    54.0     0.7            2159.0
# 8   1985.0    4.0  13.0   1.0     6.0     0.1            2160.0
# 13  1985.0    7.0   3.0   4.0    36.0    51.7            2161.0
# 18  1985.0    9.0  19.0  13.0    17.0    47.3            2162.0
#
#                                      Location Name  Latitude  Longitude  \
# 3   CHILE:  CENTRAL COAST, SAN ANTONIO, VALPARAISO   -33.132    -71.708
# 4                                       GUADELOUPE    17.013    -62.448
# 8                       INDONESIA:  DENPASAR, BALI    -9.245    114.185
# 13         PAPUA NEW GUINEA:  NEW BRITAIN:  RABAUL    -4.439    152.828
# 18                MEXICO:  MICHOACAN:  MEXICO CITY    18.190   -102.533
#
#     Focal Depth (km)  earthquake_magnitude
# 3               40.0                   8.0
# 4               13.0                   6.4
# ...

# %% [markdown]
# ### 3.3.5 Handle missing values

# %%
earthquakes.shape
# Out:
# (432, 12)

# %%
# Check for missing values
earthquakes.isnull().sum()
# Out:
# year                    0
# month                   0
# day                     0
# hour                    0
# minute                  1
# second                  2
# tsunami_event_id        0
# Location Name           0
# Latitude                0
# Longitude               0
# Focal Depth (km)        1
# earthquake_magnitude    1
# dtype: int64

# %%
nan_minute = earthquakes[earthquakes['second'].isnull() == True]

# %%
nan_minute
# Out:
#         year  month   day  hour  minute  second  tsunami_event_id  \
# 255   1992.0    1.0   5.0   6.0     NaN     NaN            2207.0
# 1703  2020.0    5.0  29.0   5.0    30.0     NaN            5748.0
#
#                 Location Name  Latitude  Longitude  Focal Depth (km)  \
# 255      CHINA:  S. CHINA SEA    18.000    108.000               8.0
# 1703  INDONESIA:  JAVA:  IJEN    -8.058    114.242               NaN
#
#       earthquake_magnitude
# 255                    3.7
# 1703                   NaN

# %% [markdown]
# **Observations:** As we're missing focal deapth and earthquake magnitude from 1703, I will drop this record. I will check the runups dataframe to get a bit more information on tsunami_event_id 2207.

# %%
filtered_runups = runups[runups['tsunami_event_id'] == 2207.0]

# %%
filtered_runups
# Out:
#           date  tsunami_event_id  earthquake_magnitude country  \
# 364 1992-01-05              2207                   3.7   CHINA
# 365 1992-01-05              2207                   3.7   CHINA
# 366 1992-01-05              2207                   3.7   CHINA
# 367 1992-01-05              2207                   3.7   CHINA
# 368 1992-01-05              2207                   3.7   CHINA
#
#                         location   latitude   longitude  distance_source_km  \
# 364  YULIN, SANYA, HAINAN ISLAND  18.230000  109.510000          161.826789
# 365    BEIBU BAY, WEIZHOU ISLAND  21.025000  109.110000          354.547217
# 366      DONGFANG, HAINAN ISLAND  19.100000  108.616667          138.067257
# 367       QINGLAN, HAINAN ISLAND  19.570000  110.820000          344.354519
# 368       XIUYING, HAINAN ISLAND  20.025917  110.280833          328.550515
#
#      max_water_height_m
# 364                0.80
# 365                0.25
# 366                0.23
# 367                0.17
# ...

# %% [markdown]
# This looks to be a small tsunami and earthquake. Imputing time seems like a bad idea so this will be dropped from the dataframe as well.

# %%
earthquakes = earthquakes.dropna()

# %%
# Check for missing values
earthquakes.isnull().sum()
# Out:
# year                    0
# month                   0
# day                     0
# hour                    0
# minute                  0
# second                  0
# tsunami_event_id        0
# Location Name           0
# Latitude                0
# Longitude               0
# Focal Depth (km)        0
# earthquake_magnitude    0
# dtype: int64

# %%
# Combine year, month, and day into a single datetime column
earthquakes['date'] = pd.to_datetime(earthquakes[['year', 'month', 'day', 'hour', 'minute', 'second']])

# Drop the original year, month, and day columns to clean up
earthquakes = earthquakes.drop(columns=['year', 'month', 'day', 'hour', 'minute','second'])

# Check the result
earthquakes.head()
# Out:
#     tsunami_event_id                                   Location Name  \
# 3             2158.0  CHILE:  CENTRAL COAST, SAN ANTONIO, VALPARAISO
# 4             2159.0                                      GUADELOUPE
# 8             2160.0                      INDONESIA:  DENPASAR, BALI
# 13            2161.0         PAPUA NEW GUINEA:  NEW BRITAIN:  RABAUL
# 18            2162.0                MEXICO:  MICHOACAN:  MEXICO CITY
#
#     Latitude  Longitude  Focal Depth (km)  earthquake_magnitude  \
# 3    -33.132    -71.708              40.0                   8.0
# 4     17.013    -62.448              13.0                   6.4
# 8     -9.245    114.185              99.0                   6.2
# 13    -4.439    152.828              46.0                   7.2
# 18    18.190   -102.533              28.0                   8.1
#
#                       date
# 3  1985-03-03 22:47:09.500
# 4  1985-03-16 14:54:00.700
# 8  1985-04-13 01:06:00.100
# 13 1985-07-03 04:36:51.700
# ...

# %%
# Rename column names for clarity
earthquakes.rename(columns = {'Location Name':'eq_location', 'Latitude':'eq_lat', 'Longitude':'eq_long','Focal Depth (km)': 'eq_depth_km', 'date':'eq_date'}, inplace = True)

# %%
earthquakes.columns
# Out:
# Index(['tsunami_event_id', 'eq_location', 'eq_lat', 'eq_long', 'eq_depth_km',
#        'earthquake_magnitude', 'eq_date'],
#       dtype='object')

# %%
# Reorder columns so that 'date' is the first column
earthquakes = earthquakes[['eq_date', 'tsunami_event_id', 'eq_location', 'eq_lat', 'eq_long', 'eq_depth_km',
       'earthquake_magnitude']]

earthquakes.head()
# Out:
#                    eq_date  tsunami_event_id  \
# 3  1985-03-03 22:47:09.500            2158.0
# 4  1985-03-16 14:54:00.700            2159.0
# 8  1985-04-13 01:06:00.100            2160.0
# 13 1985-07-03 04:36:51.700            2161.0
# 18 1985-09-19 13:17:47.300            2162.0
#
#                                        eq_location  eq_lat  eq_long  \
# 3   CHILE:  CENTRAL COAST, SAN ANTONIO, VALPARAISO -33.132  -71.708
# 4                                       GUADELOUPE  17.013  -62.448
# 8                       INDONESIA:  DENPASAR, BALI  -9.245  114.185
# 13         PAPUA NEW GUINEA:  NEW BRITAIN:  RABAUL  -4.439  152.828
# 18                MEXICO:  MICHOACAN:  MEXICO CITY  18.190 -102.533
#
#     eq_depth_km  earthquake_magnitude
# 3          40.0                   8.0
# 4          13.0                   6.4
# 8          99.0                   6.2
# 13         46.0                   7.2
# 18         28.0                   8.1

# %% [markdown]
# ## 3.4 Combine Aggregate Tsunami and Earthquake Dataframes

# %%
tsunamis.head()
# Out:
#    tsunami_event_id       date  unique_countries_count  \
# 0              2158 1985-03-03                       7
# 1              2159 1985-03-16                       1
# 2              2161 1985-07-03                       1
# 3              2162 1985-09-19                       8
# 4              2163 1985-09-21                       2
#
#                                            countries  earthquake_magnitude  \
# 0  USA, ECUADOR, JAPAN, CHINA, FRENCH POLYNESIA, ...                   8.0
# 1                      GUADELOUPE (FRENCH TERRITORY)                   6.4
# 2                                   PAPUA NEW GUINEA                   7.3
# 3  USA TERRITORY, ECUADOR, EL SALVADOR, USA, MEXI...                   8.0
# 4                                 MEXICO, COSTA RICA                   7.6
#
#    max_water_height  min_distance  max_distance  runup_count
# 0              3.50      6.872275  18671.336544           61
# ...

# %%
# Rename column names for clarity
tsunamis.rename(columns = {'date':'ts_date','earthquake_magnitude':'tsu_eq_mag'}, inplace = True)

# %%
tsunamis.columns
# Out:
# Index(['tsunami_event_id', 'ts_date', 'unique_countries_count', 'countries',
#        'tsu_eq_mag', 'max_water_height', 'min_distance', 'max_distance',
#        'runup_count'],
#       dtype='object')

# %%
# Perform inner join on tsunami_event_id
merged_df = pd.merge(tsunamis, earthquakes, on="tsunami_event_id", how="inner")

merged_df.head()
# Out:
#    tsunami_event_id    ts_date  unique_countries_count  \
# 0              2158 1985-03-03                       7
# 1              2159 1985-03-16                       1
# 2              2161 1985-07-03                       1
# 3              2162 1985-09-19                       8
# 4              2163 1985-09-21                       2
#
#                                            countries  tsu_eq_mag  \
# 0  USA, ECUADOR, JAPAN, CHINA, FRENCH POLYNESIA, ...         8.0
# 1                      GUADELOUPE (FRENCH TERRITORY)         6.4
# 2                                   PAPUA NEW GUINEA         7.3
# 3  USA TERRITORY, ECUADOR, EL SALVADOR, USA, MEXI...         8.0
# 4                                 MEXICO, COSTA RICA         7.6
#
#    max_water_height  min_distance  max_distance  runup_count  \
# 0              3.50      6.872275  18671.336544           61
# 1              0.12    136.591891    136.591891            1
# ...

# %%
merged_df.shape
# Out:
# (342, 15)

# %%
merged_df["is_equal"] = merged_df["tsu_eq_mag"] == merged_df["earthquake_magnitude"]

# %%
mismatch_count = merged_df["is_equal"].value_counts()
print(mismatch_count)
# Out:
# is_equal
# True     325
# False     17
# Name: count, dtype: int64

# %%
mismatched_df = merged_df[merged_df["is_equal"] == False]

mismatched_df[['tsu_eq_mag','earthquake_magnitude']]
# Out:
#      tsu_eq_mag  earthquake_magnitude
# 2           7.3                   7.2
# 3           8.0                   8.1
# 6           7.8                   8.1
# 7           6.7                   6.3
# 8           7.4                   7.6
# 9           7.6                   7.3
# 13          7.0                   6.8
# 14          7.4                   7.7
# 17          7.2                   6.7
# 21          8.1                   8.2
# 22          6.5                   6.1
# 23          7.1                   6.9
# 25          6.5                   6.6
# 36          7.2                   7.1
# 37          7.3                   7.5
# 117         8.0                   7.9
# 338         6.3                   6.5

# %% [markdown]
# **Observation:** Interesting to see that there are some inconsistencies with the earthquake magnitude across the tsunami and earthquake datasets (despite coming from the same database). Mostly these are a difference between 0.1-0.4; this doesn't feel significant enough to worry about. We will retain the earthquake data and drop the tsunami data.

# %%
# Group by tsunami_event_id and check unique magnitudes per group
inconsistent_events = runups.groupby('tsunami_event_id')['earthquake_magnitude'].nunique()
inconsistent_events = inconsistent_events[inconsistent_events > 1]

# Display inconsistent cases
if not inconsistent_events.empty:
    print("Inconsistencies found in the following tsunami_event_ids:")
    print(inconsistent_events)
else:
    print("All runups have consistent earthquake_magnitude values per tsunami_event_id.")
# Out:
# All runups have consistent earthquake_magnitude values per tsunami_event_id.

# %%
merged_df.columns
# Out:
# Index(['tsunami_event_id', 'ts_date', 'unique_countries_count', 'countries',
#        'tsu_eq_mag', 'max_water_height', 'min_distance', 'max_distance',
#        'runup_count', 'eq_date', 'eq_location', 'eq_lat', 'eq_long',
#        'eq_depth_km', 'earthquake_magnitude', 'is_equal'],
#       dtype='object')

# %%
# Create a new DataFrame with only the selected columns
earthquake_tsunami = merged_df[['eq_date', 'eq_location', 'eq_lat', 'eq_long', 'eq_depth_km', 'earthquake_magnitude',
                   'tsunami_event_id','runup_count','max_water_height',
                    'min_distance','max_distance','unique_countries_count', 'countries']]

earthquake_tsunami.head()
# Out:
#                   eq_date                                     eq_location  \
# 0 1985-03-03 22:47:09.500  CHILE:  CENTRAL COAST, SAN ANTONIO, VALPARAISO
# 1 1985-03-16 14:54:00.700                                      GUADELOUPE
# 2 1985-07-03 04:36:51.700         PAPUA NEW GUINEA:  NEW BRITAIN:  RABAUL
# 3 1985-09-19 13:17:47.300                MEXICO:  MICHOACAN:  MEXICO CITY
# 4 1985-09-21 01:37:13.400                 MEXICO:  SW COAST:  MEXICO CITY
#
#    eq_lat  eq_long  eq_depth_km  earthquake_magnitude  tsunami_event_id  \
# 0 -33.132  -71.708         40.0                   8.0              2158
# 1  17.013  -62.448         13.0                   6.4              2159
# 2  -4.439  152.828         46.0                   7.2              2161
# 3  18.190 -102.533         28.0                   8.1              2162
# 4  17.802 -101.647         31.0                   7.6              2163
#
#    runup_count  max_water_height  min_distance  max_distance  \
# ...

# %%
earthquake_tsunami = earthquake_tsunami.rename(columns={
    'eq_date': 'date',
    'eq_location': 'location',
    'eq_lat': 'latitude',
    'eq_long': 'longitude',
    'eq_depth_km': 'depth_km',
    'max_water_height': 'max_water_height_m',
    'tsunami_event_id': 'tsunami_id',
    'min_distance': 'min_source_dist_km',
    'max_distance': 'max_source_dist_km'})

# %%
earthquake_tsunami.columns
# Out:
# Index(['date', 'location', 'latitude', 'longitude', 'depth_km',
#        'earthquake_magnitude', 'tsunami_id', 'runup_count',
#        'max_water_height_m', 'min_source_dist_km', 'max_source_dist_km',
#        'unique_countries_count', 'countries'],
#       dtype='object')

# %% [markdown]
# # 4.0 Exploratory EDA

# %% [markdown]
# ## 4.1 Frequency Tables

# %% [markdown]
# ### 4.1.1 Runups Dataframe

# %%
# Frequency distribution and mode for Country

runups['country'].value_counts()
# Out:
# country
# JAPAN                7037
# INDONESIA            1714
# CHILE                1691
# USA                  1236
# SRI LANKA             369
#                      ...
# ALGERIA                 1
# HONDURAS                1
# CAPE VERDE              1
# AZORES (PORTUGAL)       1
# UK                      1
# Name: count, Length: 87, dtype: int64

# %% [markdown]
# __Observations:__ There are 87 countries in which tsunami's (and subsequent runups) have been recorded in the time period 1985-2024. The majority of tsunami's occur in Japan, followed by Indonesia, Chile and the USA.

# %%
# Frequency distribution for Location Name

runups['location'].value_counts()
# Out:
# location
# MIYAGI PREFECTURE, TOHOKU REGION       2314
# IWATE PREFECTURE, TOHOKU REGION        1616
# ACEH, SUMATRA                           321
# HOKKAIDO PREFECTURE                     307
# FUKUSHIMA PREFECTURE, TOHOKU REGION     259
#                                        ...
# WELLAODAYA                                1
# PARANJAMADU                               1
# KATHANKUDI                                1
# MATARA TOWN                               1
# CHALA                                     1
# Name: count, Length: 5285, dtype: int64

# %% [markdown]
# __Observation:__ Most runups occur in the Miyagi Prefecture, Tohoku Region of Japan.

# %% [markdown]
# ### 4.1.2 earthquake_tsunami dataframe

# %%
# Plot tsunami's over time
import matplotlib.pyplot as plt

# Set the bins (e.g., by decade)
earthquake_tsunami['year'] = earthquake_tsunami['date'].dt.year
bins = range(earthquake_tsunami['year'].min(), earthquake_tsunami['year'].max() + 5, 5)  # Decadal bins

# Plot histogram
plt.figure(figsize=(10, 5))
plt.hist(earthquake_tsunami['year'], bins=bins, edgecolor='black', alpha=0.7)

plt.xlabel('Year')
plt.ylabel('Number of Tsunamis')
plt.title('Distribution of Tsunamis Over Time')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### 4.2 Descriptive Statistics

# %% [markdown]
# __Note:__ I only want to calculate descriptive statistics for my quantitaive variables. As such, I'll create a subset of these first.

# %%
runups.columns
# Out:
# Index(['date', 'tsunami_event_id', 'earthquake_magnitude', 'country',
#        'location', 'latitude', 'longitude', 'distance_source_km',
#        'max_water_height_m'],
#       dtype='object')

# %%
# Create a subset excluding the categorical variables.

sub = runups[['earthquake_magnitude','latitude', 'longitude', 'distance_source_km', 'max_water_height_m',]]

# %%
# Print descriptive statistics fro the df_prods dataframe
ds = sub.describe().round(2)
ds
# Out:
#        earthquake_magnitude  latitude  longitude  distance_source_km  \
# count              17076.00  17076.00   17076.00            17076.00
# mean                   8.46     16.28      57.57             1919.07
# std                    0.73     27.46     113.66             3621.48
# min                    3.70    -77.85    -179.80                1.31
# 25%                    7.90     -6.85     -71.33              106.49
# 50%                    8.80     32.68     125.28              201.62
# 75%                    9.10     38.76     141.50             1735.12
# max                    9.10     64.50     179.30            19265.83
#
#        max_water_height_m
# count            17076.00
# mean                 4.55
# std                  5.78
# min                  0.00
# 25%                  0.39
# 50%                  2.58
# 75%                  6.03
# max                 50.90

# %% [markdown]
# __Observations:__ Most variables have full counts except for the Earthquake Magnitude variable which has been handled with a flag. For most variables, the max and min values look as expected. Only thing a little strange that _Max Water Height (m)_ has a measurement of 0.

# %%
# Check if 'runups' is a DataFrame
print(type(runups))  # It should return <class 'pandas.core.frame.DataFrame'>
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
zero = runups[runups['max_water_height_m'] == 0.00]

# %%
zero.shape
# Out:
# (118, 9)

# %%
zero
# Out:
#            date  tsunami_event_id  earthquake_magnitude           country  \
# 362  1996-02-17              2260                   8.2             JAPAN
# 1097 2002-09-08              2398                   7.6  PAPUA NEW GUINEA
# 328  2006-07-17              2832                   7.7         INDONESIA
# 1427 2009-09-29              4440                   8.1               USA
# 1428 2009-09-29              4440                   8.1             CHILE
# ...         ...               ...                   ...               ...
# 2506 2020-07-22              5753                   7.8               USA
# 2507 2020-07-22              5753                   7.8               USA
# 2508 2020-07-22              5753                   7.8               USA
# 2869 2021-03-04              5769                   7.3       NEW ZEALAND
# 4569 2024-08-17              5923                   7.0            RUSSIA
#
#                                  location  latitude   longitude  \
# ...

# %%
tsunamis_zero = runups[runups['tsunami_event_id'].isin(zero['tsunami_event_id'])]

# %%
tsunamis_zero
# Out:
#            date  tsunami_event_id  earthquake_magnitude      country  \
# 277  1996-02-17              2260                   8.2          USA
# 278  1996-02-17              2260                   8.2          USA
# 279  1996-02-17              2260                   8.2    INDONESIA
# 280  1996-02-17              2260                   8.2    INDONESIA
# 281  1996-02-17              2260                   8.2    INDONESIA
# ...         ...               ...                   ...          ...
# 2867 2021-03-04              5769                   7.3  NEW ZEALAND
# 2868 2021-03-04              5769                   7.3  NEW ZEALAND
# 2869 2021-03-04              5769                   7.3  NEW ZEALAND
# 2870 2021-03-04              5769                   7.3  NEW ZEALAND
# 4569 2024-08-17              5923                   7.0       RUSSIA
#
#                                  location   latitude   longitude  \
# 277                ADAK, SWEEPER COVE, AK  51.863000 -176.632000
# ...

# %%
# Count unique Tsunami's in the tusnami_zero subset

tsunamis_zero['tsunami_event_id'].nunique()
# Out:
# 9

# %%
# Count unique Tsunami's in total dataframe subset

runups['tsunami_event_id'].nunique()
# Out:
# 343

# %% [markdown]
# **Observation:** These 0 observations only belong to 9 of the 385 tsunami's in the dataframe. I believe these may be an error, or a measurment practice in some regions and not others.
#
# Logically, it makes sense only to analyse runups with a height > 0. I will remove these from the data frame.

# %%
# Drop rows where 'Max Water Height (m)' equals 0.00
runups = runups.drop(runups[runups['max_water_height_m'] == 0.00].index)

# %%
runups.shape
# Out:
# (16906, 9)

# %%
runups['max_water_height_m'].value_counts()
# Out:
# max_water_height_m
# 0.05     299
# 0.10     269
# 0.04     268
# 0.06     233
# 0.08     230
#         ...
# 28.05      1
# 28.18      1
# 28.40      1
# 28.51      1
# 5.76       1
# Name: count, Length: 2143, dtype: int64

# %% [markdown]
# **Observation:** As we have made a change to the runups dataframe, which is the basis of our other dataframes, we will need to recreate these again.

# %%
# Group by tsunami_event_id and perform the aggregations
tsunamis = runups.groupby('tsunami_event_id').agg(
    date=('date', 'first'),
    unique_countries_count=('country', 'nunique'),  # Count of unique countries
    countries=('country', lambda x: ', '.join(x.unique())),  # List of all unique countries
    earthquake_magnitude=('earthquake_magnitude', 'max'),  # Maximum magnitude per tsunami event
    max_water_height=('max_water_height_m', 'max'),  # Max water height recorded
    min_distance=('distance_source_km', 'min'),  # Min distance recorded per tsunami
    max_distance=('distance_source_km', 'max'),  # Max distance recorded per tsunami
    runup_count=('tsunami_event_id', 'size')  # Count of records for each tsunami event
).reset_index()

# Display the aggregated dataframe
tsunamis
# Out:
#      tsunami_event_id       date  unique_countries_count  \
# 0                2158 1985-03-03                       7
# 1                2159 1985-03-16                       1
# 2                2161 1985-07-03                       1
# 3                2162 1985-09-19                       8
# 4                2163 1985-09-21                       2
# ..                ...        ...                     ...
# 337              5927 1994-09-17                       1
# 338              5931 2011-03-09                       1
# 339              5938 2024-09-23                       1
# 340              5940 2024-12-05                       1
# 341              5942 2024-12-17                       1
#
#                                              countries  earthquake_magnitude  \
# 0    USA, ECUADOR, JAPAN, CHINA, FRENCH POLYNESIA, ...                   8.0
# 1                        GUADELOUPE (FRENCH TERRITORY)                   6.4
# ...

# %%
# Rename column names for clarity
tsunamis.rename(columns = {'date':'ts_date','earthquake_magnitude':'tsu_eq_mag'}, inplace = True)

# %%
# Perform inner join on tsunami_event_id
merged_df = pd.merge(tsunamis, earthquakes, on="tsunami_event_id", how="inner")

merged_df.head()
# Out:
#    tsunami_event_id    ts_date  unique_countries_count  \
# 0              2158 1985-03-03                       7
# 1              2159 1985-03-16                       1
# 2              2161 1985-07-03                       1
# 3              2162 1985-09-19                       8
# 4              2163 1985-09-21                       2
#
#                                            countries  tsu_eq_mag  \
# 0  USA, ECUADOR, JAPAN, CHINA, FRENCH POLYNESIA, ...         8.0
# 1                      GUADELOUPE (FRENCH TERRITORY)         6.4
# 2                                   PAPUA NEW GUINEA         7.3
# 3  USA TERRITORY, ECUADOR, EL SALVADOR, USA, MEXI...         8.0
# 4                                 MEXICO, COSTA RICA         7.6
#
#    max_water_height  min_distance  max_distance  runup_count  \
# 0              3.50      6.872275  18671.336544           61
# 1              0.12    136.591891    136.591891            1
# ...

# %%
merged_df.shape
# Out:
# (341, 15)

# %%
# Create a new DataFrame with only the selected columns
earthquake_tsunami = merged_df[['eq_date', 'eq_location', 'eq_lat', 'eq_long', 'eq_depth_km', 'earthquake_magnitude',
                   'tsunami_event_id','runup_count','max_water_height',
                    'min_distance','max_distance','unique_countries_count', 'countries']]

earthquake_tsunami.head()
# Out:
#                   eq_date                                     eq_location  \
# 0 1985-03-03 22:47:09.500  CHILE:  CENTRAL COAST, SAN ANTONIO, VALPARAISO
# 1 1985-03-16 14:54:00.700                                      GUADELOUPE
# 2 1985-07-03 04:36:51.700         PAPUA NEW GUINEA:  NEW BRITAIN:  RABAUL
# 3 1985-09-19 13:17:47.300                MEXICO:  MICHOACAN:  MEXICO CITY
# 4 1985-09-21 01:37:13.400                 MEXICO:  SW COAST:  MEXICO CITY
#
#    eq_lat  eq_long  eq_depth_km  earthquake_magnitude  tsunami_event_id  \
# 0 -33.132  -71.708         40.0                   8.0              2158
# 1  17.013  -62.448         13.0                   6.4              2159
# 2  -4.439  152.828         46.0                   7.2              2161
# 3  18.190 -102.533         28.0                   8.1              2162
# 4  17.802 -101.647         31.0                   7.6              2163
#
#    runup_count  max_water_height  min_distance  max_distance  \
# ...

# %%
earthquake_tsunami = earthquake_tsunami.rename(columns={
    'eq_date': 'date',
    'eq_location': 'location',
    'eq_lat': 'latitude',
    'eq_long': 'longitude',
    'eq_depth_km': 'depth_km',
    'max_water_height': 'max_water_height_m',
    'min_distance': 'min_source_dist_km',
    'max_distance': 'max_source_dist_km'})

# %%
earthquake_tsunami.columns
# Out:
# Index(['date', 'location', 'latitude', 'longitude', 'depth_km',
#        'earthquake_magnitude', 'tsunami_event_id', 'runup_count',
#        'max_water_height_m', 'min_source_dist_km', 'max_source_dist_km',
#        'unique_countries_count', 'countries'],
#       dtype='object')

# %%
ds_tsunami = earthquake_tsunami.describe()

ds_tsunami
# Out:
#                                 date    latitude   longitude    depth_km  \
# count                            341  341.000000  341.000000  341.000000
# mean   2007-08-06 19:48:58.647214080    8.454707   53.258103   25.266862
# min       1985-03-03 22:47:09.500000  -61.825000 -179.971000    5.000000
# 25%       1996-10-18 10:50:20.800000  -16.423000  -73.125000   12.000000
# 50%              2009-09-02 07:55:01    7.881000  125.049000   21.000000
# 75%       2016-11-24 18:43:47.700000   36.939000  152.327000   33.000000
# max              2024-12-17 01:47:26   59.821000  179.444000  167.000000
# std                              NaN   29.264939  124.190189   19.169731
#
#        earthquake_magnitude  tsunami_event_id  runup_count  \
# count            341.000000        341.000000   341.000000
# mean               7.141056       4160.413490    49.563050
# min                4.600000       2158.000000     1.000000
# 25%                6.700000       2277.000000     1.000000
# ...

# %%
# Merge datasets on 'tsunami_event_id' to bring in 'depth_km'
runups = runups.merge(earthquake_tsunami[['tsunami_event_id', 'depth_km']], on='tsunami_event_id', how='left')
runups.head()  # Display the first few rows
# Out:
#         date  tsunami_event_id  earthquake_magnitude  country  \
# 0 1985-03-03              2158                   8.0      USA
# 1 1985-03-03              2158                   8.0      USA
# 2 1985-03-03              2158                   8.0      USA
# 3 1985-03-03              2158                   8.0  ECUADOR
# 4 1985-03-03              2158                   8.0      USA
#
#                  location  latitude  longitude  distance_source_km  \
# 0  ADAK, SWEEPER COVE, AK   51.8630  -176.6320        13805.592696
# 1          SAND POINT, AK   55.3370  -160.5020        12889.004338
# 2              SEWARD, AK   60.1190  -149.4270        12504.850389
# 3               GUAYAQUIL   -2.1833   -79.8833         3530.667449
# 4        HILO, HAWAII, HI   19.7303  -155.0553        10596.671496
#
#    max_water_height_m  depth_km
# 0                0.05      40.0
# 1                0.08      40.0
# 2                0.03      40.0
# 3                0.20      40.0
# ...

# %%
# Check for missing values in the new 'depth_km' column
missing_depth_km = runups['depth_km'].isna().sum()
print(f"Number of missing values in 'depth_km': {missing_depth_km}")
# Out:
# Number of missing values in 'depth_km': 5

# %%
missing_rows = runups[runups['depth_km'].isna()]
print(missing_rows)
# Out:
#           date  tsunami_event_id  earthquake_magnitude country  \
# 282 1992-01-05              2207                   3.7   CHINA
# 283 1992-01-05              2207                   3.7   CHINA
# 284 1992-01-05              2207                   3.7   CHINA
# 285 1992-01-05              2207                   3.7   CHINA
# 286 1992-01-05              2207                   3.7   CHINA
#
#                         location   latitude   longitude  distance_source_km  \
# 282  YULIN, SANYA, HAINAN ISLAND  18.230000  109.510000          161.826789
# 283    BEIBU BAY, WEIZHOU ISLAND  21.025000  109.110000          354.547217
# 284      DONGFANG, HAINAN ISLAND  19.100000  108.616667          138.067257
# 285       QINGLAN, HAINAN ISLAND  19.570000  110.820000          344.354519
# 286       XIUYING, HAINAN ISLAND  20.025917  110.280833          328.550515
#
#      max_water_height_m  depth_km
# 282                0.80       NaN
# 283                0.25       NaN
# ...

# %%
runups.dropna(subset=['depth_km'], inplace=True)

# %%
runups.shape
# Out:
# (16901, 10)

# %% [markdown]
# # 5.0 Export

# %%
# Export descriptive statistics to csv
ds.to_csv(os.path.join(path, '05 Sent to Client','descriptive_statistics_runups.csv'))

# %%
# Export descriptive statistics to csv
ds_tsunami.to_csv(os.path.join(path, '05 Sent to Client','descriptive_statistics_tsunamis.csv'))

# %%
# Export dataframe
runups.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'runups_clean.pkl'))

# %%
# Export dataframe
earthquake_tsunami.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'tsunami.pkl'))
